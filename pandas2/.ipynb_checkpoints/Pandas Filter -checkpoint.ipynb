# %%
import pandas as pd

# %%
aq = pd.read_csv('pandas2/apple_quality.csv')
print(aq.head())
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %% [markdown]
# ***Write a Pandas program to display the dimensions or shape of the dataset. Also extract the column names from the dataset.***

# %%
aq.shape
# Out:
# (4001, 9)

# %%
aq.shape[0]
# Out:
# 4001

# %%
aq.shape[1]
# Out:
# 9

# %%
aq.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %% [markdown]
# ***Write a Pandas program to select first 2 rows, 2 columns and specific two columns from dataset***

# %%
aq.iloc[:2]
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900   0.32984
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286   0.86753
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good

# %%
aq.iloc[:,:2].head()
# Out:
#    A_id      Size
# 0   0.0 -3.970049
# 1   1.0 -1.195217
# 2   2.0 -0.292024
# 3   3.0 -0.657196
# 4   4.0  1.364217

# %%
aq[['A_id', 'Quality']].head()
# Out:
#    A_id Quality
# 0   0.0    good
# 1   1.0    good
# 2   2.0     bad
# 3   3.0    good
# 4   4.0    good

# %% [markdown]
# ***Write a Pandas program to select random number of rows, fraction of random rows***

# %%
aq.sample(5)
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 643    643.0  0.036109 -0.603547   1.028799     2.846480   3.728994 -4.399010
# 3109  3109.0  3.348148 -0.676277  -0.163897     2.992265   1.339168 -1.562933
# 2840  2840.0 -1.554807 -2.672438   1.859297     2.323177   3.595074 -0.057787
# 3477  3477.0  4.051819 -4.152542  -3.270777     3.610266   4.864905 -0.433855
# 1664  1664.0 -1.643260  1.595319   0.305949     0.777089   0.502035 -1.669015
#
#            Acidity Quality
# 643    2.687006687    good
# 3109   1.284231392    good
# 2840  -0.534298775    good
# 3477   1.471594734    good
# 1664   0.200985333     bad

# %%
aq.sample(frac = 0.02)
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3339  3339.0 -3.130433 -0.053778   1.944987     0.681934   0.813864 -1.340758
# 3385  3385.0 -3.598501  1.720804   0.401611    -1.442869  -0.318517 -0.102840
# 2957  2957.0 -2.013019 -0.580230  -0.723733     1.433088  -0.324114 -0.390662
# 1299  1299.0 -1.900972 -2.560958  -3.748122     0.978780  -0.658643  2.998647
# 657    657.0 -4.096167 -0.369184   2.207994     2.432388  -2.183960  1.153428
# ...      ...       ...       ...        ...          ...        ...       ...
# 1322  1322.0 -0.789395 -0.504417   0.457129     1.882859   1.164866 -0.042113
# 1352  1352.0 -2.805145 -1.256289  -1.206807     1.272326  -2.648016  1.271345
# 1347  1347.0  0.580659 -0.231516   0.326244     1.838139   0.002568 -1.226327
# 1463  1463.0  1.046011 -3.744529  -4.502815     5.663943   1.673697 -1.039944
# 497    497.0 -2.863054 -0.858382   1.943439    -0.340980   2.701861 -0.045718
#
#            Acidity Quality
# ...

# %%
aq.isnull()
# Out:
#        A_id   Size  Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0     False  False   False      False        False      False     False
# 1     False  False   False      False        False      False     False
# 2     False  False   False      False        False      False     False
# 3     False  False   False      False        False      False     False
# 4     False  False   False      False        False      False     False
# ...     ...    ...     ...        ...          ...        ...       ...
# 3996  False  False   False      False        False      False     False
# 3997  False  False   False      False        False      False     False
# 3998  False  False   False      False        False      False     False
# 3999  False  False   False      False        False      False     False
# 4000   True   True    True       True         True       True      True
#
#       Acidity  Quality
# 0       False    False
# 1       False    False
# 2       False    False
# ...

# %% [markdown]
# ***Pandas: Find and drop the missing values***

# %%
aq.dropna()
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %% [markdown]
# ***Pandas: Remove the duplicates of a specific column in a given dataframe***

# %%
aq.drop_duplicates('Quality')
# Out:
#       A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0      0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 2      2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 4000   NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 2                           2.621636473     bad
# 4000  Created_by_Nidula_Elgiriyewithana     NaN

# %% [markdown]
# ***Write a Pandas program to filter those records where name contains "Grand" substring from mall dataset.***

# %%
mall = pd.read_csv('pandas2/List-of-shopping-malls-in-India.csv')
mall.head(15)
# Out:
#                      Name                     Location  Year  \
# 0       MGB Felicity Mall                      Nellore  2018
# 1             CMR Central  Maddilapalem, Visakhapatnam  2010
# 2           Trendset Mall      Benz Circle, Vijayawada  2015
# 3         PVP Square Mall          MG Road, Vijayawada  2014
# 4   Visakhapatnam Central     Suryabagh, Visakhapatnam  2011
# 5                P&M Mall     Patliputra colony, Patna  2011
# 6                The Mall           Frazer Road, Patna  2014
# 7       City Centre Patna           Buddha marg, Patna  2021
# 8          Patna one mall          Dak bungalow, Patna  2017
# 9            Gravity mall            Kankarbagh, Patna  2021
# 10   Vasundhra metro mall            Boring Road Patna  2013
# 11               J D mall       Exhibition Road, Patna  2018
# 12             Grand mall                  Muzaffarpur  2017
# 13               DRB mall                  Muzaffarpur  2019
# ...

# %%
mall[mall['Name'].str.contains('Grand')]
# Out:
#                                                   Name  \
# 12                                          Grand mall
# 94                                      DLF Grand Mall
# 146                            Gold Souk Grande, Kochi
# 216                      Gold Souk Grandé Mall Chennai
# 227  Spectrum Mall (Chennai) (Formerly Grand Venus ...
# 247                              The Grand Venice Mall
#
#                                               Location  Year  \
# 12                                         Muzaffarpur  2017
# 94                         Sector-28, MG Road, Gurgaon  2005
# 146                                     Vytilla, Kochi  2011
# 216                        GST Road, Vandalur, Chennai  2015
# 227                Paper Mills Road, Perambur, Chennai  2011
# 247  Kasna Gol Chakkar, Surajpur-Kasna Road, Greate...  2015
#
#               Size (Total Area )
# 12                 200,000 sq ft
# 94   210,507 sq ft (19,556.7 m2)
# 146    500,000 sq ft (46,000 m2)
# ...

# %% [markdown]
# # updating rows and cols

# %%
mall.rename(columns = {'Location':'Place'}, inplace = True)

# %%
mall.loc[2] = ['DD Mall', 'Gwalior', '2010', '80,000 sq ft (7,400 m2)']

# %%
mall.head()
# Out:
#                     Name                        Place  Year  \
# 0      MGB Felicity Mall                      Nellore  2018
# 1            CMR Central  Maddilapalem, Visakhapatnam  2010
# 2                DD Mall                      Gwalior  2010
# 3        PVP Square Mall          MG Road, Vijayawada  2014
# 4  Visakhapatnam Central     Suryabagh, Visakhapatnam  2011
#
#           Size (Total Area )
# 0  320,000 sq ft (30,000 m2)
# 1  350,000 sq ft (33,000 m2)
# 2    80,000 sq ft (7,400 m2)
# 3  427,000 sq ft (39,700 m2)
# 4  150,000 sq ft (14,000 m2)
